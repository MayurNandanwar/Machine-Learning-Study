# %%
brief :- 
--> when relation between variables and we want to find out anomaly or outlire from it 
--> Robust covariance metrix uses esimator like MCD-minimum covariance diterminant or Fast MCD to detect outlire to get
    accurate estimation of covariances.
--> method : --> calculate mea_vector = mean of each variable 
             --> deviation matrix(d)
             --> covariance matrix(c) : (deviation matrx(d)) . (transpose of deviaton matrix (dT))
             --> mahalanobis distance : sqrt(d * dT * inv(c)) ( inv(c) :- np.linalg.inv(c))
             --> user will define threshold value : common method is to find threshold for outlire using chi-square distribution
                with degree of freedom equalto no of variable 
             --> mahalanobis distance > this threshold is consider as outlire 
--> visualize relation between variables :- pair plot , regplot 

--> Degree of Freedom :you estemate parameter of population by calculation of statistic,
    The number of independent pieces of information used to calculate the statistic is called the degrees of freedom. 
    The degrees of freedom of a statistic depend on the sample size:
    example :- you have to choose 5 numbers to get sum = 100, up to 4 values you can independently choose any number 
                but for selection 5th number you have restiction because sum of selected 5 numbers should be 100.

# %% [raw]
# # univariate, bivariate and multivariate analysis
#
# https://www.enjoyalgorithms.com/blog/univariate-bivariate-multivariate-analysis

# %% [raw]
# --> This algorithm is particularly useful in situations where there are many variables that are correlated with each other.
# --> The algorithm works by first estimating the covariance matrix of the dataset. The covariance matrix represents
#     the pairwise covariances between all the variables in the dataset.
#     However, if the dataset contains outliers, the covariance matrix can be heavily influenced by these outliers,
#     leading to inaccurate estimates of the covariances.
#     To overcome this problem, the Robust Covariance algorithm uses a robust estimator of the covariance matrix,
#     such as the Minimum Covariance Determinant (MCD) estimator or the Fast-MCD estimator.
#      These estimators are less sensitive to outliers and can provide more accurate estimates of the covariance matrix.

# %% [raw]
# example of calculation of covarience metrix

# %% [markdown]
# ![covariance_metrix.PNG](attachment:covariance_metrix.PNG)

# %% [markdown]
# ![covarience_metrix_part_2.PNG](attachment:covarience_metrix_part_2.PNG)

# %% [raw]
# The resulting covariance matrix is a 3x3 matrix that represents the covariance between each pair of variables. For example, the entry in the (1,2) position represents the covariance between variables x and y, and the entry in the (2,3) position represents the covariance between variables y and z. Note that the covariance matrix is symmetric, so the entry in the (2,1) position is equal to the entry in the (1,2) position, and so on.

# %% [markdown]
# ![covarience_metrix_part_3.PNG](attachment:covarience_metrix_part_3.PNG)

# %% [raw]
# Finally, we can use these Mahalanobis distances to identify outliers.
# The threshold for identifying outliers can be determined using a chi-square distribution with degrees of
# freedom equal to the number of variables in the dataset. For example, if we choose a significance level of 0.05,
# then the threshold for a three-variable dataset is approximately 7.81 (7.81 value from chi-square table with 3 degree of freedom because we have 2 variable in dataset and 95 % of confidence lavel )
# Therefore, we identify the fourth data point (10, 20) as an outlier, since its Mahalanobis distance is
# greater than the threshold:
#
# M(x4) = 14.86 > 7.81 se this is outlire.

# %% [markdown]
# To calculate inverse of C:

# %% [markdown]
# ![covariance_metrix_part_5.PNG](attachment:covariance_metrix_part_5.PNG)

# %% [markdown]
# ![covarience_metrix_part_6.PNG](attachment:covarience_metrix_part_6.PNG)

# %% [markdown]
# ![covariance_metrx_part_7.PNG](attachment:covariance_metrx_part_7.PNG)

# %% [raw]
# Multivariate normal distribution is a probability distribution that describes the joint distribution of a set of
# random variables that are correlated with each other.
# In other words, it is a generalization of the univariate normal distribution to higher dimensions,
# where instead of a single random variable, we have multiple random variables that are correlated with each other.
#
#
# The multivariate normal distribution is characterized by a mean vector, a covariance matrix, and the number of dimensions.
# The mean vector is a vector of the means of each random variable in the distribution, and the covariance matrix describes
# the covariance between each pair of random variables.
