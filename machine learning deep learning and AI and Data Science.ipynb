# %% [markdown]
# Machine Learning :- it is subset of AI uses algorithem to analyse daata and make decision from what it has learned
#     without being programmed. machine learning is what enables machine to learn own and provide accurate prediction using
#     provided data
#
# DeepLearning = It is specialize subset of machine learning uses neural network to simulate human decisions-making
# DeepLearning can lable and categorize the information and identify patterns. it is what enables AI system to continuously
# learn on job and improve quality and accuracy of result by determining whether decision was correct.
#
#
# Artificial Neural Network reffer to simply as neural network take inspiration from biological neural network,although they
# work differently
#
# neural network in AI is collection of small computing neurons they take incomming data and learn to make decision over time
# neural network often layer very deep become more efficient for large volume of data where as Machine learning algorithm
# at one state no changes occurs in accuracy as data increases.
#
#
# Diffrence between AI and Data Science ?
#
# Data science is process of collection, organizing and analysing data to get insights or benifit hidden behind of it.
# Data science uses math, statistics , visualization and some time Ai tools like machine learning algorithm to get accuracy
# or deep learning models to draw inferences from data
#
# there is Interaction between AI and DataScience but one not subset of each other , Data Science encompasses the methods of
# preprocessing data
# where as AI includes everything that allows computer to learn how to solve problem and make inteligent decisions
# Both data science and AI can involve the use of big data that is significently large volume of data.

# %% [raw]
# API :- application programe interface

# %%
Linear Regression :
    --> In this model there is linear reation between predictors or variable or feature and targer
    
    Assumption for Linear Regression:
        -> data should be normally distributed 
        -> Homoschdasity:- homoginity in varience (x-xmean)/std
        -> there should be linear relation between predictors and target 
        -> residual plot should be symmetric around the mean 0
        -> should not be milti colineaarity 
    --> how to find out homoschedasity ?
        --> using Q-Q plot : from state.state import Q-Q plot 
        --> and residual plot using scatter plot 
    If This assumption is met then and only then confidently we say that model is better 
    
What to do when we dont have gaussian distribution ??

--> we transform variable like skewed variable try to obtain normal or gaussian transformation 

--> why do we use transformation 0r which variable we should transform or do we always need to transformation when 
    we train mL model ?
    
    -> we generaly make transformation for Linear model when we analize data through linear statistical test like ANOVA
        and when training linear model 
    -> we does not apply transformation on non linear model like tree based , nearest neoghbor and neural network 


--> methods 
    1) Logerithmic :- deals with positive data with right skewed distribution 
                    --> when have right skewed graph when we plot then we can use 
                    
                    x_new = log(x)
                    
     2) square_root :-  suitable for variable with poison distribution.This method transforms data into normal distribution 
                     :- its a form of power transformation where exponential is 1/2 and only define for positive data.
                     
                     x_new = X^1/2 or root of X
     
     3) Arcsin : Arcsin square root transformation helps in dealing with probability, or praportion and percentage.
                 --> variable X varies between 0 and 1
                 
                 --> x_new = arcsin(sqrt(X))
                    
     4) Power :  X_new = X^lambda
                 --> when we have right skewed distribution(more observation around lower value), use lambda < 1
                 --> when we have left skewed distribution (more observation around higher value), use lambda > 1
                
                --> in this transformation we have to optimize lambda so we dont use this in practice we have alternative 
                    which is BOX-COX transformation 
                    
     5) BOX-Cox :  equation  X^lambda   = (x^lambda -1)/lambda when lambda != 0
                                        = ln(X) when lambda =0
                                        
                 --> box-cox transformation includes all the transformation mensioned above from 1 to 4
                     no transformation lambda = 1
                     logerithmic transformation lambda = 0
                     reciprocal transformation lambda = -1
                     square root transformation lambda = 0.5
                     
                 --> suitable for positive variable, what to do if variable contains postivive , negative or zero values 
                     -> add constant 
                     -. use yeo-jhonson transformation 
                     
      6) yeo-jhonson : this transformation is extension of box-cox transformation and used for variable with zero and negative 
                       variable aswell as positive variable 
                       
                      --> when variable has positive values only then yeo-jhonson transformation is Box-Cox transformation of
                          X+1
                      --> when strictly nagative values in variable then this transformation is Box-Cox of -X+1 but with power 
                          2-lambda  (-x+1)^(2-lambda)
                          
                      --> if variable is mixture of positive and negative value then transformation is mixture of above 2
                      
                      
sklearn methods :
from sklearn.preprocessing import FunctionTransform

for log,sqrt,power,reciprocal,arcsin : we do not learn any params so not need to perform fit, we direct use transform 


from sklearn.preprocessing import Powertransformar, 
    --> has method='box-cox' and 'yeo-jhonson' and standardization=False (because we perform normalization)
    --> for box-cox and yeo-jhonsons :- we have to perform fit because model transformer learn how to get optimal lambda params 
                                    for diff columns.

# %% [raw]
# Decision Tree :- It is about testing the attribute and branching the cases based on result of test.
# --> Each internal node correspons to test
#
# --> used for both regression and classification model
#
# Example of how to use Gini
#
# --> if we have categorical column in dataset at that time root node is selected based on gini-impurity or gini index
#
#     --> equation is gini for prticular category of a column (Gx)= 1 - sum(p(x)^2
#
#     --> gini for column = sum((number of rows for category of column/total number of column)* (Gx))
#
#     -->impurity --> it is difficult to find data point belog to which class
#
#     --> gini impurity of column :- it tells that what is probability of giving more impurity if select perticular column
#         in equation,
#         (Gx)= 1 - sum(p(x)^2
#         we are trying to substract probabilty of occurance of classesof column then it gives us impurity

# %% [markdown]
# ![how%20to%20calculate%20gini.PNG](attachment:how%20to%20calculate%20gini.PNG)

# %% [raw]
# above calculation is just for single column
#
# --> for all column this calculation is performed
#
# ----> in calculation first do gini impurity calculation for individual category in single column = 1- sum(p^2)
#
# ----> then find gini for column = sum((number of rows for category of column/total number of column)* (Gx))  (shown in black color
#
# --> and which column has low gini impurity(shown in black color) is selected as root node (because gini inpurity equation identify impurity in perticular category so which column has less impurity that will be selected it will provide high information , and saperation will become easy to bulid tree based on column

# %% [raw]
# --> after getting root node how to build decision tree given below
# --> again for other column do same process untill all data coversa

# %% [markdown]
# ![Decision%20tree%20build.PNG](attachment:Decision%20tree%20build.PNG)

# %%
Example of how to use Entropy

# %% [raw]
# steps--> find entropy for lable column
#     ---> find entropy for individual category of single column
#     ---> find gain --> for column
#     --> find out infogain = entropy for lable(target)column - entropy for independent column
#
#     Entropy = sum(-Pi * log2(pi))
#
# see example given below

# %% [markdown]
# ![entropy%20and%20info%20gain%20calc-2.PNG](attachment:entropy%20and%20info%20gain%20calc-2.PNG)

# %% [raw]
# Entropy : - randomness in dataset is called
#
# E(L) Entropy is calculated for lable column where lable is Yes or No --> find probability of Yes and Probability of No
#
# class column at right top --> find Entropy of yes and No for single category of class column
#
# I(class) = number of category/total rows *(entropy for category(calculated for indevidual cat))
#
# the last step --> IG = E(L) - I(class)  (shown in black color)
#
#
# Disadvantage --> it takes time at time of training because it build tree , if data changes tree building from the start for new                 data but testing time it has to follow the saperation t get the answers

# %% [raw]
# how can we build Decision Tree ?
# Decision Tree is build using recursive partitioning of data
# -> recursive partitioning means ex. get all assembly parts by recursion process
#
# Information gain - Tree that increase lavel of certaininty after split
# Information gain = Enropy of node before split - waighted gain entropy after split
#
# Entropy :- measure of information disorder or measure of randomness in data
#     eq = -p * log2(p)
#
#
# for classification problem ,
# to build decision tree using information gain or Entropy
#
# for Regression problem ,
# to build Decision tree using varience reduction :-
#     varience = 1/n sum(x-x_mean)^2
#
# varience reduction :- varience of root node - varience of child node
# high varience reduction frature will be root node based on that node further split will happen.
#
#
# same calculation for reg and classification problem
#
# 1 --entropy for root node
# 2--entropy for child nodes
# 3-- entropy of root node - weighted entropy of child node
# 4 -- high information gain will be selected
#
# ex = entropy of root node = 0.68 and total record = 5
#      lets say left split has 4 record  and enropy 0.3 and right split has 1 record and entropy 0.2
#     then
#
#     step3 -- 0.68 - (4/5 *(0.3) + 1/5 *(0.2))
#
# same process for regression
# we have varience
#
#     varience of root node - weighted varience of child node
#
# use this eq : varience = 1/n sum(x-x_mean)^2  for root node
#
# same for calculation for child node
#
# then reduction process ,
#
# varience reduction = varience of root node - weighted varience of child node
# --high varience reduction will be selected

# %% [markdown]
# Logistic Regression :- This algorithm is used to solve classification problem specially binary classification problem
#
# -- this is regression classification algorithm
# -- this deos not gives output class it gives probability and based on probability we deside class this is disadvantage
#
# -- in logistic regression we use same line equation for prediction of value (y_pred = mx+c) but here in
# logistic regression we use sigmoid  1/(1-e^y_pred) this gives probability
# because we have class either 0 or 1 and result from linear equation can be any thing or big number so how can we deside
# that value belogs ti this or that class
#
# diffrent from linear regression
#
# -- cost function in Linear R = MSE : 1/2 sum(y-y_pred)^2  calculate for all points and sum of it
#
# -- cost for Logistic R :sum([-ylog(y_pred)-(1-y)log(1-y_pred)]) for 1 to m * 1/m where y= actual and y_pred = predicted by model
#
# -- see graph of (-logy)
# using this graph we can see that cost function when y= 1 then we get -log(y_pred)
#                                                 y = 0 the we get -log(1-y_pred)
#
#
# to get optimized model on that we can make prdiction for unseen or out of sample data points not seen by model yet
# we try to minimize cost function and this is done by gredient descent
#
# -- gredient descent is optimization process we use derivative of cost change parameter and we train model using this and
# test model accuracy this is iterative process where we change parameters to reach global minima point where error is near to zero
#
# Mnew = M_old - (eta) * derivative of cost   eta = this is step how fast we do process to reach global minima
#
# using this we get new M value we use it to train model and test it for accuracy and we perform this till we get satisfactory result

# %% [raw]
# SVM :- --> find best hyperplane or boundryline that has max possible distance from both class
#        --> map data points to high dimensions so easy to classify with help of kernal
#        --> selection of kernel depends of dataset. svm has RBF , linear , sigmoid , polinomial etc kernal
#        --> mostly use RBF kernel and linear
#        -->this algorithm not computationaly efficient for large size dataset because we use kernality and change dimensions
#            as requirement so it requires memory to store
#        --> hard margin and soft margin
#        --> used for binary as well as multiclass classification.
#
# Support Vector Machine (Classification):- this algorithm classify cases by identify separator
# in this we try to find the hyperplane which has maximum distance to support vecor.
#
# -- SVM maps data to high dimensional feature space so that we can categorize even when data are not linearly saperable
#
# -- linearly non saperable mean : two category can not saperated by line but curve which is case of realword problems
#
# --so svm gives optimal hiperplane or line so that we can categorize unseen unlabeled data
#
# -- how can we transfer data to other dimensions?
#     by using kernalling function :- mapping data to high dimensional space called and
#     we have type of kernelling : Linear, Radial basis Function(RBF), sigmoid and polinomial to saperate data
#     each of them has its own pros and corns. depends on data set we chose kernal by testing hypothesis
#     It is necessary to choose a good kernel function because the performance of the model depends on it.
#
#
# --how do we find right or optimized saperator or hyperplane?
# best hyper plane is one that saperate data point with large margin between two classes
# and this marginal distance we obtained by nearer vector point of two class and we pass through plane
#
# --> when to use SVM with hard margin and SVM with Soft margin ?
# When the data is linearly separable, and we don’t want to have any misclassifications, we use SVM with a hard margin.
# However, when a linear boundary is not feasible, or we want to allow some misclassifications in the hope of achieving better generality, we can opt for a soft margin for our classifier.
#
# we have two marginal plane and one best plane each plane has its own equation
# best plane = WT* X + C = 0
# marginal plane = WT*X + C >1 and WT*X + C <1 here WT is weight
#
# Advantage :
#     accurate in high dimensional space
#
# Disadvantage
# overfit when number of feature is larger than number of records
# svm not efficient computetionaly when we have big size of data because storing the kernel matrix requires memory
#
# Usecase :
#     Image Recognixation and Hand written Recognization
#     text classification
#     detecting spam
#     sentimental analysis
#     Regression , outlire detection and clustering
#
# Don’t get confused between SVM and logistic regression. Both the algorithms try to find the best hyperplane, but the main difference is logistic regression is a probabilistic approach whereas support vector machine is based on statistical approaches.

# %% [raw]
# Clustering :- Clustering is a process of gathering similar data points form K number of cluster of similar data points
#
# process step :- first define K
#                 2--> calculate destance between point
#                 3--> update cluster centroid
#                 4--> again repeate same thing untill get constant centroid
#
# How to select K ?
#
# --> value of K should be that one which cluster has inertia or within custer sum of square (wcss) minimum or distance between       data point is minimum by using Elbow(dispersion plot we find dispersion point after that no big change in wcss occur) graph     WCSS vs K we can select optimal K
#     where after value of K there is no big changes in WCSS that point is optimal
#
#
# how to evaluate(perfromace) cluster ?
# -- ways given :- random Indexing , jaccardian coefficient, purity, Entropy, shilhoutte coeeficient
# using this metrics we can able to find out how good is cluster
#
# 1-- Rand Index : total Agree / (Total Agree + Total Dis Agree)
#     there is some thing call SS = point belong to ground thruth and predicted point using algorithm is same or match
#                                 means actual and predicted is matching similar to confusion matrix
#                             Ground Truth by which i will able to compare predicted value . example of shop or shopping mall
#                             where there are persions which arrange things in right place based on what thair manager said
#                             like shoose, chinize item or other company item like headphones.
#
#                             DD = both point no belong to ground truth and prediction made by model.
#
#                             SD = ground truth saying that point belong to cluster but model reject
#
#                             DS = not belong to ground truth but belong to predicted by model
#             confusion Metrix given below
#                             predicted
#                                1    0
#                 ground truth 1 SS   SD
#                              0 DS   DD
#
#             Rand Index =  (SS + DD) / (SS+DD+SD+DS)
#
# ground truth says that point or data belong to this cluster and this is obtain by actual observation
#
#
# how confusion matrix and this Rand Index different :- there is no difference in confusion metrix we have y label given
# In here we have ground truth (actual observation) .
#
# 2-- jaccardian coeeficient : (SS)/(SS+SD+DS) -- here we have no that data points that is predicted by model and ground truth
# that point belong to this cluster

# %% [markdown]
# ![wcss%20vs%20k.PNG](attachment:wcss%20vs%20k.PNG)

# %% [markdown]
# Entropy as Evaluation Matrix
# ![entropy.PNG](attachment:entropy.PNG)

# %% [markdown]
# ![evaluation%20matrix%20Entropy.PNG](attachment:evaluation%20matrix%20Entropy.PNG)

# %% [markdown]
# ![entopy%20Evaluation%20matrix_2.PNG](attachment:entopy%20Evaluation%20matrix_2.PNG)

# %% [markdown]
# Purity = It is the percent of the total number of objects(data points) that were classified correctly,
#         in the unit range [0..1].

# %% [markdown]
# ![purity%20equation-clustering.PNG](attachment:purity%20equation-clustering.PNG)

# %% [markdown]
# ![purity-cluster_evaluation.PNG](attachment:purity-cluster_evaluation.PNG)

# %% [markdown]
# according to equation for specific cluster purity calculation
# :- class that has max count (here cluster C1 has 3 class and class T2 has  max count 53) divided by total datapoints we have 140
#                         purity = 53/140

# %% [markdown]
# for each cluster we calculate purity and then sum it

# %% [markdown]
# shillhoutte coefficient:--

# %% [markdown]
# ![shillhoutte_score_1.PNG](attachment:shillhoutte_score_1.PNG)

# %% [markdown]
# ![shillhoutte_score2.PNG](attachment:shillhoutte_score2.PNG)

# %%
KNN :- classification problem and regression problem
    --> classification operation: find k nearer point ex k = 5 then from  new data point , find 5 points and check probability for class
        ex. A,A,B,A,B = prbability A = 3/5 and B = 2/5 so for new datapoint class is A
    --> regression operation , same find 5 data pint distance (euclidean) and take average of it and this avg dist is result
       for new datapoint 

A very small value for K makes the model more sensitive to local anomalies and exceptions, giving too many
weight to these particular points. 
On the contrary, a too large value of K would make the model ignore the local structure of the distribution you
try to learn, and produce an underfitted model.
