# %% [raw]
# what is Stat ?
# --> process of collecting organizing and analysing data to get insights from it
#
# what is Data ?
# Data is information or facts in form of pictures, words, audio, vedios in a structure formate or unstructured formate
#
# Type of Stat?
# --> discriptive and Inferential
#
# What is Discriptive Stat?
# - process of summarizing organizing the data means if data not available then collect data using survey or diff process and
# organizing means after collecting data , formatting it if not in proper format and also if missing values available in
# some attribute then handle it by mean median or model
#
# what is Inferential Stat?
# --> using sample data we can make inference by doing hypothesis valudation on sample data for population
#
#
# What is Population (N)?
# --> population is dataset which is study by people of us to get some insights of it
#
# what is sample(n) ?
# --> sample is paart or subset of population
#
# sampling technique ?
# --> goal of this technique is that final sample data is the represent of population
#     example :- exit pole by media election in each area , for each area we select sample of people deside who is going to win
#                 or hight of student is one class and try to find average age or prediction that all class has similar age
#
# type of sampling ?
#
# 1) probablistic or random sampling :- we choose data randomly, each element of dataset has equal chance to selected .
#
# 2) stratified sampling :- researchers divide population into subpopulation based on charecteristics like gender, location ,
#                             interested or not ca
#
#                         --> Stratified sampling collects a random selection of a sample from within certain strata, or
#                             subgroups within the population. Each subgroup is separated from the others on the basis of
#                             a common characteristic, such as gender, race, or religion. This way, you can ensure that all
#                             subgroups of a given population are adequately represented within your sample population.
#             --> two way of sampling we can do in stratified sampling
#                 1) we can select equal number of units from stratum(group)
#                 2) we can select units from each group equal to thair proportion in total population.

# %% [raw]
# Example of statified sampling  2nd way :-

# %% [markdown]
# ![statified%20sampling%20proprtion%20selection.PNG](attachment:statified%20sampling%20proprtion%20selection.PNG)

# %% [raw]
# 3) systematic sampling :- Systematic sampling draws a random sample from the population by selecting units
#                         at regular intervals starting from a random point. This method is useful in situations where
#                         records of your population already exist
#
#                     ex .  population size 4000 and if need to get sample size 100 then
#                             regular interval will be 40 , select unit after every 40
#
# For this to work, you must be completely sure that there is no hidden pattern or hierarchical order in the sampling frame,
# as this can bias your results.
# For example, suppose you have a list of all the employees in an organization divided by department.
# If each department list is also organized by seniority (starting with the most senior person and ending
# with the most recent hire), you run the risk of only selecting the more senior or junior employees,
# depending on what number you set as your interval.

# %% [raw]
# 4) clustering Sampling :- Cluster sampling is the process of dividing the target population into groups, called clusters.
#                             A randomly selected subsection of these groups then forms your sample.
#                         Cluster sampling is an efficient approach when you want to study large, geographically dispersed populations.
#
# two type :-
# Single (or one-stage) cluster sampling, when you divide the entire population into clusters
# Multistage cluster sampling, when you divide the cluster further into more clusters, in order to narrow down the sample size
#
# Example: Single-stage cluster sampling:
# --> You are researching the perceptions of high school seniors about higher education.
#     It is not feasible to get a list of all high school seniors in your state,
#     but you are able to access your city’s data following required privacy protocols.
#
# --> Clusters are pre-existing groups, so each high school is a cluster, and you assign a number to each one of them.
#     Then, you use simple random sampling to further select clusters. How many clusters you select will depend on the
#     sample size that you need.
#
# --> Next, you contact the principal of each selected high school and ask them to collaborate with
#     you by disseminating your questionnaire to their senior students.
#
# --> Multi-stage sampling is a more complex form of cluster sampling, in which smaller groups are successively selected
# from larger populations to form the sample population used in your study.
#
# Example: Multi-stage sampling:
# --> You want to draw a sample of employees to survey.
#     In the organizational chart, you see that the company consists of 9 departments, and
#     each department consists of 2 to 4 units, resulting in 17 different units in total.
#
# --> First, you take a simple random sample of departments.
#     Then, again using simple random sampling, you select a number of units.
#     Based on the size of the population (i.e., how many employees work at the company) and your desired sample size,
#     you establish that you need to include 3 units in your sample.
#
# --> Once you have made your selection, you ask every employee working in the selected units to fill in your questionnaire.

# %% [raw]
# Diff between Stratified and cluster sampling ?
#
# In stratified sampling, you divide your population in groups (strata) that share a common characteristic
# and then select some members from every group for your sample.
#
# In cluster sampling, you use pre-existing groups to divide your population into clusters and
# then include all members from randomly selected clusters for your sample.

# %%
variable :-- it is a property or attribute of an object to which we can asign a value 
    
variable can contain two type of data :- quantitative and qualitative or categorical 
    
Quantitative :- 
    two type :- discrete :- whole number like 1, 2 , bank account number , no of child etc
                continuous :- float values ex: weight , hight etc
                        
Qualitative :- 
    three type :-
        binary :- yes or no kind 
        nominal :- categorical values with no rank , first name , last name , surname etc
        ordinal :- catyegorical values with Rank , weight from 30 to 60 in order , hight 

            
** some times variable can work more than one type
    ex. ordinal variable we have values 1 to 10 or rating of hotel 1 to 5 we can also say this variable as quantitive variable
        when we want average of rating 
    
independent variable vs dependent variable 

--> independent variable :- a variable that we manupulate in order to affect outcome of experiment.
    
--> dependent vatiable :- variable represent outcome of experiment 
    
--> control variable :- that holds constant value through out experiment.
    
--> corelation between variables 
    :- cause and effect kind :- if changes in one variable will effect the other variable we can say there is relation betwwen two 
                                corelation can exist between independent variable 
                                we can find out by variance inflation factor should < 5 between two inde. feature or variable
