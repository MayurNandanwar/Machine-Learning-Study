# %% [markdown]
# ![local_outlire_fector.PNG](attachment:local_outlire_fector.PNG)

# %% [markdown]
# ![example%20of%20LOF.PNG](attachment:example%20of%20LOF.PNG)

# %% [markdown]
# ![LOF%20example_3.PNG](attachment:LOF%20example_3.PNG)

# %% [markdown]
# ![LOF%20example%204.PNG](attachment:LOF%20example%204.PNG)
