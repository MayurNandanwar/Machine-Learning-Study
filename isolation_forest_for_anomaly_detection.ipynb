# %% [markdown]
# ![isolation_forst.PNG](attachment:isolation_forst.PNG)

# %% [markdown]
# ![isolation_forest_examp_1.PNG](attachment:isolation_forest_examp_1.PNG)

# %% [markdown]
# ![isolation_forest_example_2.PNG](attachment:isolation_forest_example_2.PNG)

# %% [markdown]
# ![isolation_forest_examp_3.PNG](attachment:isolation_forest_examp_3.PNG)
